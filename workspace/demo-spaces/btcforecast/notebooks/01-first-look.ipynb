# %% [markdown]
# # btcforecast first look\n\nInspect the sample dataset, generated labels, and simple baseline evaluation outputs.

# %%
import pandas as pd\ndf = pd.read_csv('../data/raw/sample/btcusd_1m_sample.csv')\ndf.head()

# %%
labeled = pd.read_csv('../data/processed/btcusd_1m_sample_labeled.csv')\nlabeled[['timestamp', 'close', 'future_close', 'target_up']].head()

# %%
labeled['target_up'].value_counts(dropna=False)
